# %% [markdown]
# ```mermaid
# flowchart TD
#     A[Economics] --> B[Recursos]
#     B --> C[Naturales]
#     B --> D[Humanos]
#     B --> E[Financieros]
#     B --> F[Intangibles]
#     F --> G[Ventaja Competitiva]
# ```

# %% [markdown]
# ```mermaid
# flowchart TD
#     A[Economics] --> B[Resources]
#
#     B --> C[Natural Resources]
#     C --> C1[Land]
#     C --> C2[Forests]
#     C --> C3[Minerals]
#     C --> C4[Water]
#
#     B --> D[Human Resources]
#     D --> D1[Labor]
#     D --> D2[Physical Abilities]
#     D --> D3[Mental Abilities]
#
#     B --> E[Financial Resources]
#     E --> E1[Capital]
#     E --> E2[Funds]
#
#     B --> F[Intangible Resources]
#     F --> F1[Reputation]
#     F --> F2[Quality]
#     F --> F3[Social Responsibility]
#
#     C --> G[Factors of Production]
#     D --> G
#     E --> G
#
#     G --> H[Goods and Services]
#     F --> I[Competitive Advantage]
#     H --> I
# ```

# %% [markdown]
# ```mermaid
# flowchart TD
#     A[Economics] --> B[Resources]
#
#     B --> C[Natural Resources]
#     C --> C1[Land]
#     C --> C2[Forests]
#     C --> C3[Minerals]
#     C --> C4[Water]
#
#     B --> D[Human Resources]
#     D --> D1[Labor]
#     D --> D2[Physical Abilities]
#     D --> D3[Mental Abilities]
#
#     B --> E[Financial Resources]
#     E --> E1[Capital]
#     E --> E2[Funds]
#
#     B --> F[Intangible Resources]
#     F --> F1[Reputation]
#     F --> F2[Quality]
#     F --> F3[Social Responsibility]
#
#     C --> G[Factors of Production]
#     D --> G
#     E --> G
#
#     G --> H[Goods and Services]
#     F --> I[Competitive Advantage]
#     H --> I
#
#     %% Color definitions (with black text)
#     classDef main fill:#FFD966,stroke:#333,stroke-width:2px,color:#000
#     classDef natural fill:#C6E2FF,stroke:#333,color:#000
#     classDef human fill:#C6EFCE,stroke:#333,color:#000
#     classDef financial fill:#FCE4D6,stroke:#333,color:#000
#     classDef intangible fill:#E4DFEC,stroke:#333,color:#000
#     classDef result fill:#FFF2CC,stroke:#333,color:#000
#
#     %% Apply colors
#     class A,B main
#     class C,C1,C2,C3,C4 natural
#     class D,D1,D2,D3 human
#     class E,E1,E2 financial
#     class F,F1,F2,F3 intangible
#     class G,H,I result
#
#
#     %% Flechas (colores)
#     linkStyle 0 stroke:#333,stroke-width:2px
#     linkStyle 1 stroke:#1f77b4,stroke-width:2px
#     linkStyle 2 stroke:#1f77b4,stroke-width:1.5px
#     linkStyle 3 stroke:#1f77b4,stroke-width:1.5px
#     linkStyle 4 stroke:#1f77b4,stroke-width:1.5px
#     linkStyle 5 stroke:#1f77b4,stroke-width:1.5px
#
#     linkStyle 6 stroke:#2ca02c,stroke-width:2px
#     linkStyle 7 stroke:#2ca02c,stroke-width:1.5px
#     linkStyle 8 stroke:#2ca02c,stroke-width:1.5px
#     linkStyle 9 stroke:#2ca02c,stroke-width:1.5px
#
#     linkStyle 10 stroke:#ff7f0e,stroke-width:2px
#     linkStyle 11 stroke:#ff7f0e,stroke-width:1.5px
#     linkStyle 12 stroke:#ff7f0e,stroke-width:1.5px
#
#     linkStyle 13 stroke:#9467bd,stroke-width:2px
#     linkStyle 14 stroke:#9467bd,stroke-width:1.5px
#     linkStyle 15 stroke:#9467bd,stroke-width:1.5px
#     linkStyle 16 stroke:#9467bd,stroke-width:1.5px
#
#     linkStyle 17 stroke:#8c564b,stroke-width:2px
#     linkStyle 18 stroke:#8c564b,stroke-width:2px
#     linkStyle 19 stroke:#8c564b,stroke-width:2px
# ```
